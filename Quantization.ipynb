# %%
# !pip install onnx
# !pip install onnxscript
# !pip install onnxruntime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 26.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.4/518.4 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.1 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/microsoft/onnxruntime-inference-examples.git
# Out:
# Cloning into 'onnxruntime-inference-examples'...
# remote: Enumerating objects: 4979, done.
# remote: Counting objects: 100% (1709/1709), done.
# remote: Compressing objects: 100% (908/908), done.
# remote: Total 4979 (delta 1000), reused 1093 (delta 700), pack-reused 3270
# Receiving objects: 100% (4979/4979), 394.34 MiB | 23.21 MiB/s, done.
# Resolving deltas: 100% (2048/2048), done.
# Updating files: 100% (946/946), done.

# %%
cd onnxruntime-inference-examples/quantization/image_classification/cpu/
# Out:
# /content/onnxruntime-inference-examples/quantization/image_classification/cpu

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mv /content/drive/MyDrive/model_gdnet.onnx /content/onnxruntime-inference-examples/quantization/image_classification/cpu/

# %%
# !python -m onnxruntime.quantization.preprocess --input model_gdnet.onnx --output model_gdnet-infer.onnx

# %%
# !python run.py --input_model model_gdnet-infer.onnx --output_model model_gdnet.quant.onnx --calibrate_dataset ./test_images/
# Out:
# Calibrated and quantized model saved.
# benchmarking fp32 model...
# 4130.08ms
# 4092.48ms
# 5524.25ms
# 4155.23ms
# 4129.66ms
# 5636.30ms
# 4109.52ms
# 4099.88ms
# 5582.17ms
# 4150.28ms
# Avg: 4560.98ms
# benchmarking int8 model...
# 5796.81ms
# 4873.70ms
# 6341.93ms
# 4920.01ms
# 6034.69ms
# 6379.60ms
# 4876.87ms
# 7125.31ms
# 5374.07ms
# 4976.34ms
# Avg: 5669.93ms

# %%
# !python run_qdq_debug.py --float_model model_gdnet-infer.onnx --qdq_model model_gdnet.quant.onnx --calibrate_dataset ./test_images/
# Out:
# ------------------------------------------------
#
# Comparing weights of float model vs qdq model.....
# Cross model error of 'final_fusion.ChannelGate.mlp.1.bias': 89.55476605718317
#
# Cross model error of 'final_fusion.ChannelGate.mlp.1.weight': 48.03825371068725
#
# Cross model error of 'final_fusion.ChannelGate.mlp.3.bias': 120.17456577935087
#
# Cross model error of 'final_fusion.ChannelGate.mlp.3.weight': 48.12415710672488
#
# Cross model error of 'final_predict.weight': 40.88878085531533
#
# Cross model error of 'h2l.weight': 47.09506740167715
#
# Cross model error of 'h3_conv.cbam.ChannelGate.mlp.1.bias': 57.16955264587408
#
# Cross model error of 'h3_conv.cbam.ChannelGate.mlp.1.weight': 48.040326890573304
#
# Cross model error of 'h3_conv.cbam.ChannelGate.mlp.3.bias': 79.88928480926336
#
# Cross model error of 'h3_conv.cbam.ChannelGate.mlp.3.weight': 48.10531983889787
#
# Cross model error of 'h3_conv.p1_d1.0.bias': 55.404729177419284
#
# ...
